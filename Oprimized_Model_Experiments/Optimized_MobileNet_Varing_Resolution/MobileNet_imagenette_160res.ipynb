# %% [markdown]
# <a href="https://colab.research.google.com/github/ecbme4040/e4040-2022Fall-Project-AHSN-am5964-hsp2122-ska2145/blob/main/Oprimized_Model_Experiments/Optimized_MobileNet_Varing_Resolution/MobileNet_imagenette_160res.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AHSN Project
# #### Done by:
# Safeyah Alshemali(ska2145) - Hannah Portes(hsp2122) - Aparna Muraleekrishnan(am5964)
#
# #### Based on Paper:
# MobileNets: Efficient Convolutional Neural Networks for Mobile Vision Applications
# [link](https://https://arxiv.org/abs/1704.04861)
#
# #### Authors:
# Andrew G. Howard, Menglong Zhu, Bo Chen, Dmitry Kalenichenko, Weijun Wang, Tobias Weyand, Marco Andreetto, Hartwig Adam

# %% [markdown]
# ### Code Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import keras
from keras import datasets, layers, models
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, Activation , DepthwiseConv2D
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, SeparableConv2D,  GlobalAveragePooling2D, AveragePooling2D
from keras.optimizers import Adam, RMSprop, SGD
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda, GlobalAveragePooling2D
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Data Processing

# %% [markdown]
# The data set we are using is **Imagenette** which is subset of ImageNet dataset of 10 classes only. This dataset fit the resourses (GPUS) and time limitation [link](https://https://www.tensorflow.org/datasets/catalog/imagenette).

# %%
data, info = tfds.load("imagenette/160px-v2", with_info=True, as_supervised=True)
train_data, valid_data = data['train'], data['validation']
# Out:
# Downloading and preparing dataset 94.42 MiB (download: 94.42 MiB, generated: 102.10 MiB, total: 196.52 MiB) to ~/tensorflow_datasets/imagenette/160px-v2/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/9469 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/imagenette/160px-v2/1.0.0.incomplete9TDWLR/imagenette-train.tfrecord*...:   0%…
# Generating validation examples...:   0%|          | 0/3925 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/imagenette/160px-v2/1.0.0.incomplete9TDWLR/imagenette-validation.tfrecord*...:…
# Dataset imagenette downloaded and prepared to ~/tensorflow_datasets/imagenette/160px-v2/1.0.0. Subsequent calls will reuse this data.

# %%
# resize the images to 128 x 128 for faster training 
train_dataset = train_data.map(
    lambda image, label: (tf.image.resize(image, (160, 160)), label))

validation_dataset = valid_data.map(
    lambda image, label: (tf.image.resize(image, (160, 160)), label)
)

# %%
# print general properties of the dataset for information and to verify attributes
# match what we expect
num_train = train_dataset.__len__().numpy()
num_val = validation_dataset.__len__().numpy()

num_classes = info.features['label'].num_classes
print('Total number of classes in dataset: ', num_classes)

print('Number of training samples: ', num_train)
print('Number of validation samples: ', num_val)
# Out:
# Total number of classes in dataset:  10
# Number of training samples:  9469
# Number of validation samples:  3925

# %%
get_label_name = info.features['label'].int2str

text_labels = [get_label_name(i) for i in range(num_classes)]
for idx,i in enumerate(text_labels):
    print('Label: {} , Name: {}'.format(idx, i))
# Out:
# Label: 0 , Name: n01440764
# Label: 1 , Name: n02102040
# Label: 2 , Name: n02979186
# Label: 3 , Name: n03000684
# Label: 4 , Name: n03028079
# Label: 5 , Name: n03394916
# Label: 6 , Name: n03417042
# Label: 7 , Name: n03425413
# Label: 8 , Name: n03445777
# Label: 9 , Name: n03888257

# %%
# put train and validation into a list, and one hot encode their respective labels
X_train = list(map(lambda x: x[0], train_dataset))
y_train = list(map(lambda x: x[1], train_dataset))


X_valid = list(map(lambda x: x[0], validation_dataset))
y_valid = list(map(lambda x: x[1], validation_dataset))

y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_valid = tf.keras.utils.to_categorical(y_valid, num_classes)

# %%
train_len = info.splits['train'].num_examples
validation_len = info.splits['validation'].num_examples

# Verify number of samples
print('Train size: {}'.format(train_len))
print('Validation size: {}'.format(validation_len))
# Out:
# Train size: 9469
# Validation size: 3925

# %%
# Verify shapes
print('Y Train shape: {}'.format(y_train.shape))
print('Y Validation shape: {}'.format(y_valid.shape))
# Out:
# Y Train shape: (9469, 10)
# Y Validation shape: (3925, 10)

# %% [markdown]
# ### Data Augmentation

# %%
# Define ImageGen for data augmentation 
train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=30,
      height_shift_range=0.3)

valid_datagen = ImageDataGenerator(
      rescale=1./255)

train_data = tf.keras.preprocessing.image.NumpyArrayIterator(
    x=np.array(X_train), y=np.array(y_train), image_data_generator=train_datagen,batch_size=32
)

valid_data = tf.keras.preprocessing.image.NumpyArrayIterator(
    x=np.array(X_valid), y=np.array(y_valid), image_data_generator=valid_datagen,batch_size=32
)

# %% [markdown]
# ### Data Visualization

# %%
# plot the images
plt.figure(figsize=(18, 18))

num = 0

for i in range(0, 12):
    image,label = next(iter(train_data))
    ax = plt.subplot(6, 6, num + 1)
    plt.imshow(image[0])
    plt.title(str(get_label_name(np.argmax(label))) + ' - class # ' + str(np.argmax(label)))
    plt.axis("off")
    num += 1

# %% [markdown]
# ### MobileNet Model

# %% [markdown]
# The Depthwise Separable Convolution layer

# %%
def DepthWiseConv(kernal_size, stride, x):
    result = DepthwiseConv2D(kernal_size, strides=stride , padding='same')(x)
    result = BatchNormalization()(result)
    result = Activation('relu')(result)
    return result

# %%
def PointWiseConv(filters,kernal_size, stride, x):
    result = Conv2D(filters, kernel_size=kernal_size, strides=stride)(x)
    result = BatchNormalization()(result)
    result = Activation('relu')(result)
    return result

# %% [markdown]
# Model Creation

# %%
def create_MobileNet_model(input_shape, no_classes):
    
    print('layer 1 input', input_shape)

    #first layer (Conv/s2)
    input = Input(shape= input_shape)
    x = Conv2D(32, kernel_size=(3, 3), strides=(2, 2) ,padding='same', use_bias=False)(input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    print('layer 2 input', x.shape)
    #second layer (Conv dw/s1) + (Conv /s1)
    x = DepthWiseConv((3,3), (1,1), x)
    x = PointWiseConv(64,(1, 1), (1, 1) ,x)

    print('layer 3 input', x.shape)
    #third layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(128,(1, 1), (1, 1) ,x)
    
    print('layer 5 input', x.shape)
    #5th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(256,(1, 1), (1, 1) ,x)

    print('layer 7 input', x.shape)
    #7th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(512,(1, 1), (1, 1) ,x)

    print('layer 9 input', x.shape)
    #9th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(1024,(1, 1), (1, 1) ,x)

    x = Dropout(0.2)(x)

    print('Avg Pooling input', x.shape)
    #11th layer: Avg Pooling (7*7)
    x = GlobalAveragePooling2D()(x) 

    print('Dense 12 input', x.shape)
    #12th layer : Affine layer
    out = Dense(no_classes,activation='softmax')(x)

    print('out', out.shape)

    model = Model(input, out, name='mobilenet')

    return model

# %% [markdown]
# Fitting and Training the Model

# %%
MobileNet = create_MobileNet_model((160,160,3),10)
MobileNet.summary()
# Out:
# layer 1 input (160, 160, 3)
# layer 2 input (None, 80, 80, 32)
# layer 3 input (None, 80, 80, 64)
# layer 5 input (None, 40, 40, 128)
# layer 7 input (None, 20, 20, 256)
# layer 9 input (None, 10, 10, 512)
# Avg Pooling input (None, 5, 5, 1024)
# Flatten input (None, 1024)
# Dense 12 input (None, 1024)
# out (None, 10)
# Model: "mobilenet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  conv2d (Conv2D)             (None, 80, 80, 32)        864
#
#  batch_normalization (BatchN  (None, 80, 80, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 80, 80, 32)        0
#
#  depthwise_conv2d (Depthwise  (None, 80, 80, 32)       320
#  Conv2D)
#
#  batch_normalization_1 (Batc  (None, 80, 80, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 80, 80, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 80, 80, 64)        2112
#
#  batch_normalization_2 (Batc  (None, 80, 80, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 80, 80, 64)        0
#
#  depthwise_conv2d_1 (Depthwi  (None, 40, 40, 64)       640
#  seConv2D)
#
#  batch_normalization_3 (Batc  (None, 40, 40, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 40, 40, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 40, 40, 128)       8320
#
#  batch_normalization_4 (Batc  (None, 40, 40, 128)      512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 40, 40, 128)       0
#
#  depthwise_conv2d_2 (Depthwi  (None, 20, 20, 128)      1280
#  seConv2D)
#
#  batch_normalization_5 (Batc  (None, 20, 20, 128)      512
#  hNormalization)
#
#  activation_5 (Activation)   (None, 20, 20, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 256)       33024
#
#  batch_normalization_6 (Batc  (None, 20, 20, 256)      1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 20, 20, 256)       0
#
#  depthwise_conv2d_3 (Depthwi  (None, 10, 10, 256)      2560
#  seConv2D)
#
#  batch_normalization_7 (Batc  (None, 10, 10, 256)      1024
#  hNormalization)
#
#  activation_7 (Activation)   (None, 10, 10, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 512)       131584
#
#  batch_normalization_8 (Batc  (None, 10, 10, 512)      2048
#  hNormalization)
#
#  activation_8 (Activation)   (None, 10, 10, 512)       0
#
#  depthwise_conv2d_4 (Depthwi  (None, 5, 5, 512)        5120
#  seConv2D)
#
#  batch_normalization_9 (Batc  (None, 5, 5, 512)        2048
#  hNormalization)
#
#  activation_9 (Activation)   (None, 5, 5, 512)         0
#
#  conv2d_5 (Conv2D)           (None, 5, 5, 1024)        525312
#
#  batch_normalization_10 (Bat  (None, 5, 5, 1024)       4096
#  chNormalization)
#
#  activation_10 (Activation)  (None, 5, 5, 1024)        0
#
#  dropout (Dropout)           (None, 5, 5, 1024)        0
#
#  global_average_pooling2d (G  (None, 1024)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 10)                10250
#
# =================================================================
# Total params: 733,418
# Trainable params: 727,402
# Non-trainable params: 6,016
# _________________________________________________________________

# %%
# MobileNet.compile(optimizer='adam',
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])
# MobileNet.fit(train_data, epochs=20, validation_data=valid_data, verbose=1)

MobileNet.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])


checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=True,verbose=1, monitor='accuracy')

history = MobileNet.fit(train_data, epochs=25, validation_data=valid_data, callbacks=[model_checkpoint_callback], shuffle=True)

MobileNet.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/25
# 296/296 [==============================] - ETA: 0s - loss: 1.7244 - accuracy: 0.4066
# Epoch 1: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 443s 1s/step - loss: 1.7244 - accuracy: 0.4066 - val_loss: 3.6449 - val_accuracy: 0.1017
# Epoch 2/25
# 296/296 [==============================] - ETA: 0s - loss: 1.4197 - accuracy: 0.5248
# Epoch 2: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 437s 1s/step - loss: 1.4197 - accuracy: 0.5248 - val_loss: 2.8269 - val_accuracy: 0.2576
# Epoch 3/25
# 296/296 [==============================] - ETA: 0s - loss: 1.2351 - accuracy: 0.5933
# Epoch 3: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 436s 1s/step - loss: 1.2351 - accuracy: 0.5933 - val_loss: 2.0310 - val_accuracy: 0.4581
# Epoch 4/25
# 296/296 [==============================] - ETA: 0s - loss: 1.1186 - accuracy: 0.6335
# Epoch 4: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 434s 1s/step - loss: 1.1186 - accuracy: 0.6335 - val_loss: 1.3026 - val_accuracy: 0.6033
# Epoch 5/25
# 296/296 [==============================] - ETA: 0s - loss: 1.0218 - accuracy: 0.6696
# Epoch 5: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 436s 1s/step - loss: 1.0218 - accuracy: 0.6696 - val_loss: 1.5085 - val_accuracy: 0.5473
# Epoch 6/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9307 - accuracy: 0.6936
# Epoch 6: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 435s 1s/step - loss: 0.9307 - accuracy: 0.6936 - val_loss: 1.3242 - val_accuracy: 0.6071
# Epoch 7/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8709 - accuracy: 0.7127
# Epoch 7: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 434s 1s/step - loss: 0.8709 - accuracy: 0.7127 - val_loss: 1.8568 - val_accuracy: 0.5276
# Epoch 8/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8249 - accuracy: 0.7313
# Epoch 8: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 442s 1s/step - loss: 0.8249 - accuracy: 0.7313 - val_loss: 1.3791 - val_accuracy: 0.5880
# Epoch 9/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7665 - accuracy: 0.7507
# Epoch 9: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 437s 1s/step - loss: 0.7665 - accuracy: 0.7507 - val_loss: 1.0675 - val_accuracy: 0.6772
# Epoch 10/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7280 - accuracy: 0.7552
# Epoch 10: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 436s 1s/step - loss: 0.7280 - accuracy: 0.7552 - val_loss: 1.2108 - val_accuracy: 0.6673
# Epoch 11/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7017 - accuracy: 0.7683
# Epoch 11: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 439s 1s/step - loss: 0.7017 - accuracy: 0.7683 - val_loss: 1.2239 - val_accuracy: 0.6550
# Epoch 12/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6639 - accuracy: 0.7803
# Epoch 12: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 437s 1s/step - loss: 0.6639 - accuracy: 0.7803 - val_loss: 1.2019 - val_accuracy: 0.6461
# Epoch 13/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6379 - accuracy: 0.7908
# Epoch 13: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 440s 1s/step - loss: 0.6379 - accuracy: 0.7908 - val_loss: 1.6561 - val_accuracy: 0.5689
# Epoch 14/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6088 - accuracy: 0.7983
# Epoch 14: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 434s 1s/step - loss: 0.6088 - accuracy: 0.7983 - val_loss: 1.1455 - val_accuracy: 0.6772
# Epoch 15/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5629 - accuracy: 0.8157
# Epoch 15: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 436s 1s/step - loss: 0.5629 - accuracy: 0.8157 - val_loss: 1.0582 - val_accuracy: 0.6989
# Epoch 16/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5404 - accuracy: 0.8244
# Epoch 16: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 433s 1s/step - loss: 0.5404 - accuracy: 0.8244 - val_loss: 0.8608 - val_accuracy: 0.7516
# Epoch 17/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5193 - accuracy: 0.8271
# Epoch 17: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 435s 1s/step - loss: 0.5193 - accuracy: 0.8271 - val_loss: 1.3722 - val_accuracy: 0.6306
# Epoch 18/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4965 - accuracy: 0.8342
# Epoch 18: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 434s 1s/step - loss: 0.4965 - accuracy: 0.8342 - val_loss: 1.1148 - val_accuracy: 0.6805
# Epoch 19/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4709 - accuracy: 0.8495
# Epoch 19: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 434s 1s/step - loss: 0.4709 - accuracy: 0.8495 - val_loss: 0.8937 - val_accuracy: 0.7524
# Epoch 20/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4488 - accuracy: 0.8533
# Epoch 20: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 434s 1s/step - loss: 0.4488 - accuracy: 0.8533 - val_loss: 1.3485 - val_accuracy: 0.6520
# Epoch 21/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4385 - accuracy: 0.8572
# Epoch 21: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 435s 1s/step - loss: 0.4385 - accuracy: 0.8572 - val_loss: 1.1949 - val_accuracy: 0.6879
# Epoch 22/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4272 - accuracy: 0.8563
# Epoch 22: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 438s 1s/step - loss: 0.4272 - accuracy: 0.8563 - val_loss: 1.3011 - val_accuracy: 0.6558
# Epoch 23/25
# 296/296 [==============================] - ETA: 0s - loss: 0.3968 - accuracy: 0.8677
# Epoch 23: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 435s 1s/step - loss: 0.3968 - accuracy: 0.8677 - val_loss: 1.1121 - val_accuracy: 0.7144
# Epoch 24/25
# 296/296 [==============================] - ETA: 0s - loss: 0.3878 - accuracy: 0.8734
# Epoch 24: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 437s 1s/step - loss: 0.3878 - accuracy: 0.8734 - val_loss: 1.1142 - val_accuracy: 0.7284
# Epoch 25/25
# 296/296 [==============================] - ETA: 0s - loss: 0.3553 - accuracy: 0.8787
# Epoch 25: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 436s 1s/step - loss: 0.3553 - accuracy: 0.8787 - val_loss: 1.1455 - val_accuracy: 0.7060

# %% [markdown]
# Plot the Training and Validation acuuracy and Loss

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')

plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
