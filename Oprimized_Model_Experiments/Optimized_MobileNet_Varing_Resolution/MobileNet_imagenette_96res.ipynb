# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import keras
from keras import datasets, layers, models
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, Activation , DepthwiseConv2D
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, SeparableConv2D,  GlobalAveragePooling2D, AveragePooling2D
from keras.optimizers import Adam, RMSprop, SGD
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda, GlobalAveragePooling2D
from keras.preprocessing.image import ImageDataGenerator

# %%
data, info = tfds.load("imagenette/160px-v2", with_info=True, as_supervised=True)
train_data, valid_data = data['train'], data['validation']
# Out:
# Downloading and preparing dataset 94.42 MiB (download: 94.42 MiB, generated: 102.10 MiB, total: 196.52 MiB) to ~/tensorflow_datasets/imagenette/160px-v2/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/9469 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/imagenette/160px-v2/1.0.0.incomplete9SW4R9/imagenette-train.tfrecord*...:   0%…
# Generating validation examples...:   0%|          | 0/3925 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/imagenette/160px-v2/1.0.0.incomplete9SW4R9/imagenette-validation.tfrecord*...:…
# Dataset imagenette downloaded and prepared to ~/tensorflow_datasets/imagenette/160px-v2/1.0.0. Subsequent calls will reuse this data.

# %%
train_dataset = train_data.map(
    lambda image, label: (tf.image.resize(image, (96, 96)), label))

validation_dataset = valid_data.map(
    lambda image, label: (tf.image.resize(image, (96, 96)), label)
)

# %%
num_train = train_dataset.__len__().numpy()
num_val = validation_dataset.__len__().numpy()

num_classes = info.features['label'].num_classes
print('Total number of classes in dataset: ', num_classes)

print('Number of training samples: ', num_train)
print('Number of validation samples: ', num_val)
# Out:
# Total number of classes in dataset:  10
# Number of training samples:  9469
# Number of validation samples:  3925

# %%
get_label_name = info.features['label'].int2str

text_labels = [get_label_name(i) for i in range(num_classes)]
for idx,i in enumerate(text_labels):
    print('Label: {} , Name: {}'.format(idx, i))
# Out:
# Label: 0 , Name: n01440764
# Label: 1 , Name: n02102040
# Label: 2 , Name: n02979186
# Label: 3 , Name: n03000684
# Label: 4 , Name: n03028079
# Label: 5 , Name: n03394916
# Label: 6 , Name: n03417042
# Label: 7 , Name: n03425413
# Label: 8 , Name: n03445777
# Label: 9 , Name: n03888257

# %%
X_train = list(map(lambda x: x[0], train_dataset))
y_train = list(map(lambda x: x[1], train_dataset))


X_valid = list(map(lambda x: x[0], validation_dataset))
y_valid = list(map(lambda x: x[1], validation_dataset))

y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_valid = tf.keras.utils.to_categorical(y_valid, num_classes)

# %%
train_len = info.splits['train'].num_examples
validation_len = info.splits['validation'].num_examples

print('Train size: {}'.format(train_len))
print('Validation size: {}'.format(validation_len))
# Out:
# Train size: 9469
# Validation size: 3925

# %%
print('Y Train shape: {}'.format(y_train.shape))
print('Y Validation shape: {}'.format(y_valid.shape))
# Out:
# Y Train shape: (9469, 10)
# Y Validation shape: (3925, 10)

# %%
train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=30,
      height_shift_range=0.3)

valid_datagen = ImageDataGenerator(
      rescale=1./255)

train_data = tf.keras.preprocessing.image.NumpyArrayIterator(
    x=np.array(X_train), y=np.array(y_train), image_data_generator=train_datagen,batch_size=32
)

valid_data = tf.keras.preprocessing.image.NumpyArrayIterator(
    x=np.array(X_valid), y=np.array(y_valid), image_data_generator=valid_datagen,batch_size=32
)

# %%
plt.figure(figsize=(18, 18))

num = 0

for i in range(0, 12):
    image,label = next(iter(train_data))
    ax = plt.subplot(6, 6, num + 1)
    plt.imshow(image[0])
    plt.title(str(get_label_name(np.argmax(label))) + ' - class # ' + str(np.argmax(label)))
    plt.axis("off")
    num += 1

# %%
def create_MobileNet_model(input_shape, alpha, no_classes):
    
    print('layer 1 input', input_shape)

    #first layer (Conv/s2)
    input = Input(shape= input_shape)
    x = Conv2D(int(alpha*32), kernel_size=(3, 3), strides=(2, 2) ,padding='same', use_bias=False)(input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    print('layer 2 input', x.shape)
    #second layer (Conv dw/s1) + (Conv /s1)
    x = DepthWiseConv((3,3), (1,1), x)
    x = PointWiseConv(int(alpha*64),(1, 1), (1, 1) ,x)

    print('layer 3 input', x.shape)
    #third layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(int(alpha*128),(1, 1), (1, 1) ,x)
    
    # print('layer 4 input', x.shape)
    # #4th layer (Conv dw/s1) + (Conv /s1)
    # x = DepthWiseConv((3,3), (1,1), x)
    # x = PointWiseConv(128,(1, 1), (1, 1) ,x)

    print('layer 5 input', x.shape)
    #5th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(int(alpha*256),(1, 1), (1, 1) ,x)

    # print('layer 6 input', x.shape)
    # #6th layer (Conv dw/s1) + (Conv /s1)
    # x = DepthWiseConv((3,3), (1,1), x)
    # x = PointWiseConv(256,(1, 1), (1, 1) ,x)

    print('layer 7 input', x.shape)
    #7th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(int(alpha*512),(1, 1), (1, 1) ,x)

    # print('layer 8 stack input', x.shape)
    # #8thlayer: 5 * (Conv dw/s1) + (Conv dw /s1)
    # for _ in range(5):
    #   x = DepthWiseConv((3,3), (1,1), x)
    #   x = PointWiseConv(512,(1, 1), (1, 1) ,x)

    print('layer 9 input', x.shape)
    #9th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(int(alpha*1024),(1, 1), (1, 1) ,x)

    x = Dropout(0.2)(x)

    # print('layer 10 input', x.shape)
    # #10th layer (Conv dw/s2) + (Conv /s1)
    # x = DepthWiseConv((3,3), (1,1), x)
    # x = PointWiseConv(1024,(1, 1), (1, 1) ,x)

    print('Avg Pooling input', x.shape)
    #11th layer: Avg Pooling (7*7)
    x = GlobalAveragePooling2D()(x) 

    print('Flatten input', x.shape)
    #print('Flatten layer input', x.shape)
    #Flatten layer / s1? 
    #x = Flatten()(x)

    print('Dense 12 input', x.shape)
    #12th layer : Affine layer
    out = Dense(no_classes,activation='softmax')(x)

    print('out', out.shape)

    model = Model(input, out, name='mobilenet')

    return model

# %%
def DepthWiseConv(kernal_size, stride, x):
    result = DepthwiseConv2D(kernal_size, strides=stride , padding='same')(x)
    result = BatchNormalization()(result)
    result = Activation('relu')(result)
    return result

# %%
def PointWiseConv(filters,kernal_size, stride, x):
    result = Conv2D(filters, kernel_size=kernal_size, strides=stride)(x)
    result = BatchNormalization()(result)
    result = Activation('relu')(result)
    return result

# %%
MobileNet = create_MobileNet_model((96,96,3),1.0,10)
MobileNet.summary()
# Out:
# layer 1 input (96, 96, 3)
# layer 2 input (None, 48, 48, 32)
# layer 3 input (None, 48, 48, 64)
# layer 5 input (None, 24, 24, 128)
# layer 7 input (None, 12, 12, 256)
# layer 9 input (None, 6, 6, 512)
# Avg Pooling input (None, 3, 3, 1024)
# Flatten input (None, 1024)
# Dense 12 input (None, 1024)
# out (None, 10)
# Model: "mobilenet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  conv2d_6 (Conv2D)           (None, 48, 48, 32)        864
#
#  batch_normalization_11 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  activation_11 (Activation)  (None, 48, 48, 32)        0
#
#  depthwise_conv2d_5 (Depthwi  (None, 48, 48, 32)       320
#  seConv2D)
#
#  batch_normalization_12 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  activation_12 (Activation)  (None, 48, 48, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 48, 48, 64)        2112
#
#  batch_normalization_13 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  activation_13 (Activation)  (None, 48, 48, 64)        0
#
#  depthwise_conv2d_6 (Depthwi  (None, 24, 24, 64)       640
#  seConv2D)
#
#  batch_normalization_14 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  activation_14 (Activation)  (None, 24, 24, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 24, 24, 128)       8320
#
#  batch_normalization_15 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  activation_15 (Activation)  (None, 24, 24, 128)       0
#
#  depthwise_conv2d_7 (Depthwi  (None, 12, 12, 128)      1280
#  seConv2D)
#
#  batch_normalization_16 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  activation_16 (Activation)  (None, 12, 12, 128)       0
#
#  conv2d_9 (Conv2D)           (None, 12, 12, 256)       33024
#
#  batch_normalization_17 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  activation_17 (Activation)  (None, 12, 12, 256)       0
#
#  depthwise_conv2d_8 (Depthwi  (None, 6, 6, 256)        2560
#  seConv2D)
#
#  batch_normalization_18 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  activation_18 (Activation)  (None, 6, 6, 256)         0
#
#  conv2d_10 (Conv2D)          (None, 6, 6, 512)         131584
#
#  batch_normalization_19 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  activation_19 (Activation)  (None, 6, 6, 512)         0
#
#  depthwise_conv2d_9 (Depthwi  (None, 3, 3, 512)        5120
#  seConv2D)
#
#  batch_normalization_20 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  activation_20 (Activation)  (None, 3, 3, 512)         0
#
#  conv2d_11 (Conv2D)          (None, 3, 3, 1024)        525312
#
#  batch_normalization_21 (Bat  (None, 3, 3, 1024)       4096
#  chNormalization)
#
#  activation_21 (Activation)  (None, 3, 3, 1024)        0
#
#  dropout_1 (Dropout)         (None, 3, 3, 1024)        0
#
#  global_average_pooling2d_1   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 733,418
# Trainable params: 727,402
# Non-trainable params: 6,016
# _________________________________________________________________

# %%
# MobileNet.compile(optimizer='adam',
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])
# MobileNet.fit(train_data, epochs=20, validation_data=valid_data, verbose=1)

MobileNet.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])


checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=True,verbose=1, monitor='accuracy')

history = MobileNet.fit(train_data, epochs=25, validation_data=valid_data, callbacks=[model_checkpoint_callback], shuffle=True)

MobileNet.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/25
# 296/296 [==============================] - ETA: 0s - loss: 1.7847 - accuracy: 0.3882
# Epoch 1: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 36s 88ms/step - loss: 1.7847 - accuracy: 0.3882 - val_loss: 2.8757 - val_accuracy: 0.0986
# Epoch 2/25
# 296/296 [==============================] - ETA: 0s - loss: 1.4719 - accuracy: 0.5086
# Epoch 2: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 86ms/step - loss: 1.4719 - accuracy: 0.5086 - val_loss: 1.6744 - val_accuracy: 0.4372
# Epoch 3/25
# 296/296 [==============================] - ETA: 0s - loss: 1.2908 - accuracy: 0.5721
# Epoch 3: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 85ms/step - loss: 1.2908 - accuracy: 0.5721 - val_loss: 1.5444 - val_accuracy: 0.5139
# Epoch 4/25
# 296/296 [==============================] - ETA: 0s - loss: 1.1717 - accuracy: 0.6153
# Epoch 4: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 85ms/step - loss: 1.1717 - accuracy: 0.6153 - val_loss: 1.7447 - val_accuracy: 0.5116
# Epoch 5/25
# 296/296 [==============================] - ETA: 0s - loss: 1.0810 - accuracy: 0.6466
# Epoch 5: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 85ms/step - loss: 1.0810 - accuracy: 0.6466 - val_loss: 1.6714 - val_accuracy: 0.5317
# Epoch 6/25
# 296/296 [==============================] - ETA: 0s - loss: 1.0233 - accuracy: 0.6686
# Epoch 6: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 85ms/step - loss: 1.0233 - accuracy: 0.6686 - val_loss: 1.1793 - val_accuracy: 0.6357
# Epoch 7/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9528 - accuracy: 0.6834
# Epoch 7: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 85ms/step - loss: 0.9528 - accuracy: 0.6834 - val_loss: 1.4246 - val_accuracy: 0.5613
# Epoch 8/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9066 - accuracy: 0.6994
# Epoch 8: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 85ms/step - loss: 0.9066 - accuracy: 0.6994 - val_loss: 1.5347 - val_accuracy: 0.5473
# Epoch 9/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8592 - accuracy: 0.7188
# Epoch 9: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 84ms/step - loss: 0.8592 - accuracy: 0.7188 - val_loss: 1.7424 - val_accuracy: 0.5417
# Epoch 10/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8184 - accuracy: 0.7296
# Epoch 10: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 84ms/step - loss: 0.8184 - accuracy: 0.7296 - val_loss: 1.2782 - val_accuracy: 0.6273
# Epoch 11/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7748 - accuracy: 0.7449
# Epoch 11: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 84ms/step - loss: 0.7748 - accuracy: 0.7449 - val_loss: 1.4410 - val_accuracy: 0.5873
# Epoch 12/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7279 - accuracy: 0.7573
# Epoch 12: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 85ms/step - loss: 0.7279 - accuracy: 0.7573 - val_loss: 1.4478 - val_accuracy: 0.6051
# Epoch 13/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7007 - accuracy: 0.7686
# Epoch 13: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 85ms/step - loss: 0.7007 - accuracy: 0.7686 - val_loss: 1.0681 - val_accuracy: 0.6899
# Epoch 14/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6563 - accuracy: 0.7815
# Epoch 14: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 85ms/step - loss: 0.6563 - accuracy: 0.7815 - val_loss: 1.1622 - val_accuracy: 0.6754
# Epoch 15/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6405 - accuracy: 0.7862
# Epoch 15: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 84ms/step - loss: 0.6405 - accuracy: 0.7862 - val_loss: 1.1589 - val_accuracy: 0.6606
# Epoch 16/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6136 - accuracy: 0.7984
# Epoch 16: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 84ms/step - loss: 0.6136 - accuracy: 0.7984 - val_loss: 1.7459 - val_accuracy: 0.6023
# Epoch 17/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5959 - accuracy: 0.7998
# Epoch 17: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 84ms/step - loss: 0.5959 - accuracy: 0.7998 - val_loss: 1.3758 - val_accuracy: 0.6318
# Epoch 18/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5688 - accuracy: 0.8119
# Epoch 18: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 85ms/step - loss: 0.5688 - accuracy: 0.8119 - val_loss: 2.0582 - val_accuracy: 0.5524
# Epoch 19/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5317 - accuracy: 0.8231
# Epoch 19: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 84ms/step - loss: 0.5317 - accuracy: 0.8231 - val_loss: 1.1237 - val_accuracy: 0.6882
# Epoch 20/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5107 - accuracy: 0.8250
# Epoch 20: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 85ms/step - loss: 0.5107 - accuracy: 0.8250 - val_loss: 1.6219 - val_accuracy: 0.6326
# Epoch 21/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4853 - accuracy: 0.8350
# Epoch 21: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 84ms/step - loss: 0.4853 - accuracy: 0.8350 - val_loss: 1.2665 - val_accuracy: 0.6739
# Epoch 22/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4701 - accuracy: 0.8413
# Epoch 22: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 84ms/step - loss: 0.4701 - accuracy: 0.8413 - val_loss: 1.1286 - val_accuracy: 0.7269
# Epoch 23/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4530 - accuracy: 0.8480
# Epoch 23: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 84ms/step - loss: 0.4530 - accuracy: 0.8480 - val_loss: 1.5596 - val_accuracy: 0.6555
# Epoch 24/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4251 - accuracy: 0.8546
# Epoch 24: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 85ms/step - loss: 0.4251 - accuracy: 0.8546 - val_loss: 1.7240 - val_accuracy: 0.6186
# Epoch 25/25
# 296/296 [==============================] - ETA: 0s - loss: 0.3947 - accuracy: 0.8678
# Epoch 25: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 25s 84ms/step - loss: 0.3947 - accuracy: 0.8678 - val_loss: 1.2364 - val_accuracy: 0.6945

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')

plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# !rm -rf ./tmp/checkpoint

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('MobileNet Model 96 Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('MobileNet Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

print("run timing with gpu - 25*25s ")
# Out:
# run timing with gpu - 25*25s
