# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import keras
from keras import datasets, layers, models
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, Activation , DepthwiseConv2D
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, SeparableConv2D,  GlobalAveragePooling2D, AveragePooling2D
from keras.optimizers import Adam, RMSprop, SGD
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda, GlobalAveragePooling2D
from keras.preprocessing.image import ImageDataGenerator

# %%
data, info = tfds.load("imagenette/160px-v2", with_info=True, as_supervised=True)
train_data, valid_data = data['train'], data['validation']

# %%
train_dataset = train_data.map(
    lambda image, label: (tf.image.resize(image, (128, 128)), label))

validation_dataset = valid_data.map(
    lambda image, label: (tf.image.resize(image, (128, 128)), label)
)

# %%
num_train = train_dataset.__len__().numpy()
num_val = validation_dataset.__len__().numpy()

num_classes = info.features['label'].num_classes
print('Total number of classes in dataset: ', num_classes)

print('Number of training samples: ', num_train)
print('Number of validation samples: ', num_val)
# Out:
# Total number of classes in dataset:  10
# Number of training samples:  9469
# Number of validation samples:  3925

# %%
get_label_name = info.features['label'].int2str

text_labels = [get_label_name(i) for i in range(num_classes)]
for idx,i in enumerate(text_labels):
    print('Label: {} , Name: {}'.format(idx, i))
# Out:
# Label: 0 , Name: n01440764
# Label: 1 , Name: n02102040
# Label: 2 , Name: n02979186
# Label: 3 , Name: n03000684
# Label: 4 , Name: n03028079
# Label: 5 , Name: n03394916
# Label: 6 , Name: n03417042
# Label: 7 , Name: n03425413
# Label: 8 , Name: n03445777
# Label: 9 , Name: n03888257

# %%
X_train = list(map(lambda x: x[0], train_dataset))
y_train = list(map(lambda x: x[1], train_dataset))


X_valid = list(map(lambda x: x[0], validation_dataset))
y_valid = list(map(lambda x: x[1], validation_dataset))

y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_valid = tf.keras.utils.to_categorical(y_valid, num_classes)

# %%
train_len = info.splits['train'].num_examples
validation_len = info.splits['validation'].num_examples

print('Train size: {}'.format(train_len))
print('Validation size: {}'.format(validation_len))
# Out:
# Train size: 9469
# Validation size: 3925

# %%
print('Y Train shape: {}'.format(y_train.shape))
print('Y Validation shape: {}'.format(y_valid.shape))
# Out:
# Y Train shape: (9469, 10)
# Y Validation shape: (3925, 10)

# %%
train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=30,
      height_shift_range=0.3)

valid_datagen = ImageDataGenerator(
      rescale=1./255)

train_data = tf.keras.preprocessing.image.NumpyArrayIterator(
    x=np.array(X_train), y=np.array(y_train), image_data_generator=train_datagen,batch_size=32
)

valid_data = tf.keras.preprocessing.image.NumpyArrayIterator(
    x=np.array(X_valid), y=np.array(y_valid), image_data_generator=valid_datagen,batch_size=32
)

# %%
plt.figure(figsize=(18, 18))

num = 0

for i in range(0, 12):
    image,label = next(iter(train_data))
    ax = plt.subplot(6, 6, num + 1)
    plt.imshow(image[0])
    plt.title(str(get_label_name(np.argmax(label))) + ' - class # ' + str(np.argmax(label)))
    plt.axis("off")
    num += 1

# %%
def create_MobileNet_model(input_shape, alpha, no_classes):
    
    print('layer 1 input', input_shape)

    #first layer (Conv/s2)
    input = Input(shape= input_shape)
    x = Conv2D(int(alpha*32), kernel_size=(3, 3), strides=(2, 2) ,padding='same', use_bias=False)(input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    print('layer 2 input', x.shape)
    #second layer (Conv dw/s1) + (Conv /s1)
    x = DepthWiseConv((3,3), (1,1), x)
    x = PointWiseConv(int(alpha*64),(1, 1), (1, 1) ,x)

    print('layer 3 input', x.shape)
    #third layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(int(alpha*128),(1, 1), (1, 1) ,x)
    
    # print('layer 4 input', x.shape)
    # #4th layer (Conv dw/s1) + (Conv /s1)
    # x = DepthWiseConv((3,3), (1,1), x)
    # x = PointWiseConv(128,(1, 1), (1, 1) ,x)

    print('layer 5 input', x.shape)
    #5th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(int(alpha*256),(1, 1), (1, 1) ,x)

    # print('layer 6 input', x.shape)
    # #6th layer (Conv dw/s1) + (Conv /s1)
    # x = DepthWiseConv((3,3), (1,1), x)
    # x = PointWiseConv(256,(1, 1), (1, 1) ,x)

    print('layer 7 input', x.shape)
    #7th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(int(alpha*512),(1, 1), (1, 1) ,x)

    # print('layer 8 stack input', x.shape)
    # #8thlayer: 5 * (Conv dw/s1) + (Conv dw /s1)
    # for _ in range(5):
    #   x = DepthWiseConv((3,3), (1,1), x)
    #   x = PointWiseConv(512,(1, 1), (1, 1) ,x)

    print('layer 9 input', x.shape)
    #9th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(int(alpha*1024),(1, 1), (1, 1) ,x)

    x = Dropout(0.2)(x)

    # print('layer 10 input', x.shape)
    # #10th layer (Conv dw/s2) + (Conv /s1)
    # x = DepthWiseConv((3,3), (1,1), x)
    # x = PointWiseConv(1024,(1, 1), (1, 1) ,x)

    print('Avg Pooling input', x.shape)
    #11th layer: Avg Pooling (7*7)
    x = GlobalAveragePooling2D()(x) 

    print('Flatten input', x.shape)
    #print('Flatten layer input', x.shape)
    #Flatten layer / s1? 
    #x = Flatten()(x)

    print('Dense 12 input', x.shape)
    #12th layer : Affine layer
    out = Dense(no_classes,activation='softmax')(x)

    print('out', out.shape)

    model = Model(input, out, name='mobilenet')

    return model

# %%
def DepthWiseConv(kernal_size, stride, x):
    result = DepthwiseConv2D(kernal_size, strides=stride , padding='same')(x)
    result = BatchNormalization()(result)
    result = Activation('relu')(result)
    return result

# %%
def PointWiseConv(filters,kernal_size, stride, x):
    result = Conv2D(filters, kernel_size=kernal_size, strides=stride)(x)
    result = BatchNormalization()(result)
    result = Activation('relu')(result)
    return result

# %%
MobileNet = create_MobileNet_model((128,128,3),0.75,10)
MobileNet.summary()
# Out:
# layer 1 input (128, 128, 3)
# layer 2 input (None, 64, 64, 24)
# layer 3 input (None, 64, 64, 48)
# layer 5 input (None, 32, 32, 96)
# layer 7 input (None, 16, 16, 192)
# layer 9 input (None, 8, 8, 384)
# Avg Pooling input (None, 4, 4, 768)
# Flatten input (None, 768)
# Dense 12 input (None, 768)
# out (None, 10)
# Model: "mobilenet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  conv2d (Conv2D)             (None, 64, 64, 24)        648
#
#  batch_normalization (BatchN  (None, 64, 64, 24)       96
#  ormalization)
#
#  activation (Activation)     (None, 64, 64, 24)        0
#
#  depthwise_conv2d (Depthwise  (None, 64, 64, 24)       240
#  Conv2D)
#
#  batch_normalization_1 (Batc  (None, 64, 64, 24)       96
#  hNormalization)
#
#  activation_1 (Activation)   (None, 64, 64, 24)        0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 48)        1200
#
#  batch_normalization_2 (Batc  (None, 64, 64, 48)       192
#  hNormalization)
#
#  activation_2 (Activation)   (None, 64, 64, 48)        0
#
#  depthwise_conv2d_1 (Depthwi  (None, 32, 32, 48)       480
#  seConv2D)
#
#  batch_normalization_3 (Batc  (None, 32, 32, 48)       192
#  hNormalization)
#
#  activation_3 (Activation)   (None, 32, 32, 48)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 96)        4704
#
#  batch_normalization_4 (Batc  (None, 32, 32, 96)       384
#  hNormalization)
#
#  activation_4 (Activation)   (None, 32, 32, 96)        0
#
#  depthwise_conv2d_2 (Depthwi  (None, 16, 16, 96)       960
#  seConv2D)
#
#  batch_normalization_5 (Batc  (None, 16, 16, 96)       384
#  hNormalization)
#
#  activation_5 (Activation)   (None, 16, 16, 96)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 192)       18624
#
#  batch_normalization_6 (Batc  (None, 16, 16, 192)      768
#  hNormalization)
#
#  activation_6 (Activation)   (None, 16, 16, 192)       0
#
#  depthwise_conv2d_3 (Depthwi  (None, 8, 8, 192)        1920
#  seConv2D)
#
#  batch_normalization_7 (Batc  (None, 8, 8, 192)        768
#  hNormalization)
#
#  activation_7 (Activation)   (None, 8, 8, 192)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 384)         74112
#
#  batch_normalization_8 (Batc  (None, 8, 8, 384)        1536
#  hNormalization)
#
#  activation_8 (Activation)   (None, 8, 8, 384)         0
#
#  depthwise_conv2d_4 (Depthwi  (None, 4, 4, 384)        3840
#  seConv2D)
#
#  batch_normalization_9 (Batc  (None, 4, 4, 384)        1536
#  hNormalization)
#
#  activation_9 (Activation)   (None, 4, 4, 384)         0
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 768)         295680
#
#  batch_normalization_10 (Bat  (None, 4, 4, 768)        3072
#  chNormalization)
#
#  activation_10 (Activation)  (None, 4, 4, 768)         0
#
#  dropout (Dropout)           (None, 4, 4, 768)         0
#
#  global_average_pooling2d (G  (None, 768)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 10)                7690
#
# =================================================================
# Total params: 419,122
# Trainable params: 414,610
# Non-trainable params: 4,512
# _________________________________________________________________

# %%
# MobileNet.compile(optimizer='adam',
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])
# MobileNet.fit(train_data, epochs=20, validation_data=valid_data, verbose=1)

MobileNet.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])


checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=True,verbose=1, monitor='accuracy')

history = MobileNet.fit(train_data, epochs=25, validation_data=valid_data, callbacks=[model_checkpoint_callback], shuffle=True)

MobileNet.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/25
# 296/296 [==============================] - ETA: 0s - loss: 1.7429 - accuracy: 0.3978
# Epoch 1: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 236s 791ms/step - loss: 1.7429 - accuracy: 0.3978 - val_loss: 2.7729 - val_accuracy: 0.0986
# Epoch 2/25
# 296/296 [==============================] - ETA: 0s - loss: 1.4528 - accuracy: 0.5201
# Epoch 2: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 225s 761ms/step - loss: 1.4528 - accuracy: 0.5201 - val_loss: 2.1796 - val_accuracy: 0.3159
# Epoch 3/25
# 296/296 [==============================] - ETA: 0s - loss: 1.2936 - accuracy: 0.5692
# Epoch 3: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 228s 770ms/step - loss: 1.2936 - accuracy: 0.5692 - val_loss: 2.0178 - val_accuracy: 0.4729
# Epoch 4/25
# 296/296 [==============================] - ETA: 0s - loss: 1.1835 - accuracy: 0.6098
# Epoch 4: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 230s 778ms/step - loss: 1.1835 - accuracy: 0.6098 - val_loss: 1.4223 - val_accuracy: 0.5730
# Epoch 5/25
# 296/296 [==============================] - ETA: 0s - loss: 1.0849 - accuracy: 0.6475
# Epoch 5: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 231s 781ms/step - loss: 1.0849 - accuracy: 0.6475 - val_loss: 1.1589 - val_accuracy: 0.6352
# Epoch 6/25
# 296/296 [==============================] - ETA: 0s - loss: 1.0196 - accuracy: 0.6653
# Epoch 6: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 233s 788ms/step - loss: 1.0196 - accuracy: 0.6653 - val_loss: 1.9107 - val_accuracy: 0.5228
# Epoch 7/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9614 - accuracy: 0.6849
# Epoch 7: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 232s 785ms/step - loss: 0.9614 - accuracy: 0.6849 - val_loss: 1.2931 - val_accuracy: 0.6043
# Epoch 8/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9065 - accuracy: 0.6987
# Epoch 8: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 231s 779ms/step - loss: 0.9065 - accuracy: 0.6987 - val_loss: 1.1123 - val_accuracy: 0.6543
# Epoch 9/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8723 - accuracy: 0.7181
# Epoch 9: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 230s 776ms/step - loss: 0.8723 - accuracy: 0.7181 - val_loss: 1.1796 - val_accuracy: 0.6459
# Epoch 10/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8309 - accuracy: 0.7296
# Epoch 10: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 230s 776ms/step - loss: 0.8309 - accuracy: 0.7296 - val_loss: 1.2063 - val_accuracy: 0.6415
# Epoch 11/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7991 - accuracy: 0.7427
# Epoch 11: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 229s 773ms/step - loss: 0.7991 - accuracy: 0.7427 - val_loss: 1.2455 - val_accuracy: 0.6311
# Epoch 12/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7593 - accuracy: 0.7465
# Epoch 12: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 228s 769ms/step - loss: 0.7593 - accuracy: 0.7465 - val_loss: 1.1880 - val_accuracy: 0.6576
# Epoch 13/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7213 - accuracy: 0.7638
# Epoch 13: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 229s 772ms/step - loss: 0.7213 - accuracy: 0.7638 - val_loss: 1.4466 - val_accuracy: 0.6097
# Epoch 14/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6962 - accuracy: 0.7715
# Epoch 14: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 226s 763ms/step - loss: 0.6962 - accuracy: 0.7715 - val_loss: 1.7589 - val_accuracy: 0.5569
# Epoch 15/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6732 - accuracy: 0.7777
# Epoch 15: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 222s 751ms/step - loss: 0.6732 - accuracy: 0.7777 - val_loss: 0.9975 - val_accuracy: 0.6996
# Epoch 16/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6483 - accuracy: 0.7856
# Epoch 16: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 229s 772ms/step - loss: 0.6483 - accuracy: 0.7856 - val_loss: 1.2843 - val_accuracy: 0.6326
# Epoch 17/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6256 - accuracy: 0.7943
# Epoch 17: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 225s 761ms/step - loss: 0.6256 - accuracy: 0.7943 - val_loss: 1.2573 - val_accuracy: 0.6655
# Epoch 18/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5924 - accuracy: 0.8042
# Epoch 18: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 224s 758ms/step - loss: 0.5924 - accuracy: 0.8042 - val_loss: 1.0513 - val_accuracy: 0.7131
# Epoch 19/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5835 - accuracy: 0.8065
# Epoch 19: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 224s 757ms/step - loss: 0.5835 - accuracy: 0.8065 - val_loss: 1.1121 - val_accuracy: 0.6805
# Epoch 20/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5392 - accuracy: 0.8197
# Epoch 20: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 231s 779ms/step - loss: 0.5392 - accuracy: 0.8197 - val_loss: 1.3471 - val_accuracy: 0.6624
# Epoch 21/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5360 - accuracy: 0.8228
# Epoch 21: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 234s 792ms/step - loss: 0.5360 - accuracy: 0.8228 - val_loss: 1.0238 - val_accuracy: 0.7164
# Epoch 22/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5063 - accuracy: 0.8326
# Epoch 22: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 232s 784ms/step - loss: 0.5063 - accuracy: 0.8326 - val_loss: 1.0942 - val_accuracy: 0.6899
# Epoch 23/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4964 - accuracy: 0.8370
# Epoch 23: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 235s 793ms/step - loss: 0.4964 - accuracy: 0.8370 - val_loss: 1.0213 - val_accuracy: 0.7080
# Epoch 24/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4742 - accuracy: 0.8414
# Epoch 24: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 234s 790ms/step - loss: 0.4742 - accuracy: 0.8414 - val_loss: 1.1011 - val_accuracy: 0.7131
# Epoch 25/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4725 - accuracy: 0.8437
# Epoch 25: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 233s 788ms/step - loss: 0.4725 - accuracy: 0.8437 - val_loss: 1.0067 - val_accuracy: 0.7208

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')

plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# !rm -rf ./tmp/checkpoint

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('MobileNet Model alpha=0.75 Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('MobileNet Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

print("run timing - 230*25s ")
# Out:
# run timing - 230*25s
