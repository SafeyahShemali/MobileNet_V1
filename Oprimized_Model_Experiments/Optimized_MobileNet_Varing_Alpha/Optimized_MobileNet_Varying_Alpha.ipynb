# %% [markdown]
# # AHSN Project
# #### Done by:
# Safeyah Alshemali - Hannah  Portes - Aparna Muraleekrishnan
#
# #### Based on Paper:
# MobileNets: Efficient Convolutional Neural Networks for Mobile Vision Applications
# [link](https://https://arxiv.org/abs/1704.04861)
#
# #### Authors:
# Andrew G. Howard, Menglong Zhu, Bo Chen, Dmitry Kalenichenko, Weijun Wang, Tobias Weyand, Marco Andreetto, Hartwig Adam

# %% [markdown]
# ### Code Libraries

# %% [markdown]
# Below is the process of loading the data of Imagenette. This tensorflow dataset has 10 classes, 9469 training samples, and 3925 validation samples.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import time
import os

# Import Necessary Modules
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import keras
from keras import datasets, layers, models
from keras.models import Model
from keras.layers import Dense, Dropout, Input, Activation , DepthwiseConv2D, Conv2D, BatchNormalization,  GlobalAveragePooling2D, Activation , Lambda , Reshape
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Data Processing

# %% [markdown]
# The data set we are using is **Imagenette** which is subset of ImageNet dataset of 10 classes only. This dataset fit the resourses (GPUS) and time limitation [link](https://https://www.tensorflow.org/datasets/catalog/imagenette).

# %%
# load the data and info from tfds
data, info = tfds.load("imagenette/160px-v2", with_info=True, as_supervised=True)

# then split into training and validation subsets
train_data, valid_data = data['train'], data['validation']
# Out:
# Downloading and preparing dataset 94.42 MiB (download: 94.42 MiB, generated: 102.10 MiB, total: 196.52 MiB) to ~/tensorflow_datasets/imagenette/160px-v2/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/9469 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/imagenette/160px-v2/1.0.0.incompleteSATJHE/imagenette-train.tfrecord*...:   0%…
# Generating validation examples...:   0%|          | 0/3925 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/imagenette/160px-v2/1.0.0.incompleteSATJHE/imagenette-validation.tfrecord*...:…
# Dataset imagenette downloaded and prepared to ~/tensorflow_datasets/imagenette/160px-v2/1.0.0. Subsequent calls will reuse this data.

# %%
image_size = 128
no_classes = 10
# resize the images to 128 x 128 for faster training 
train_dataset = train_data.map(lambda image, label: (tf.image.resize(image, (image_size, image_size)), label))

validation_dataset = valid_data.map(
    lambda image, label: (tf.image.resize(image, (image_size, image_size)), label))

# %%
# print general properties of the dataset for information and to verify attributes
# match what we expect
num_train = train_dataset.__len__().numpy()
num_val = validation_dataset.__len__().numpy()

num_classes = info.features['label'].num_classes
print('Total number of classes in dataset: ', num_classes)
print('Number of training samples: ', num_train)
print('Number of validation samples: ', num_val)
# Out:
# Total number of classes in dataset:  10
# Number of training samples:  9469
# Number of validation samples:  3925

# %%
# put train and validation into a list, and one hot encode their respective labels
X_train = list(map(lambda x: x[0], train_dataset))
y_train = list(map(lambda x: x[1], train_dataset))


X_valid = list(map(lambda x: x[0], validation_dataset))
y_valid = list(map(lambda x: x[1], validation_dataset))

y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_valid = tf.keras.utils.to_categorical(y_valid, num_classes)

# %%
# Verify shapes
print('Y Train shape: {}'.format(y_train.shape))
print('Y Validation shape: {}'.format(y_valid.shape))
# Out:
# Y Train shape: (9469, 10)
# Y Validation shape: (3925, 10)

# %% [markdown]
# ### Data Augmentation

# %%
# Define ImageGen for data augmentation 

train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=30,
      height_shift_range=0.3)

valid_datagen = ImageDataGenerator(
      rescale=1./255)

train_data = tf.keras.preprocessing.image.NumpyArrayIterator(
    x=np.array(X_train), y=np.array(y_train), image_data_generator=train_datagen,batch_size=32
)

valid_data = tf.keras.preprocessing.image.NumpyArrayIterator(
    x=np.array(X_valid), y=np.array(y_valid), image_data_generator=valid_datagen,batch_size=32
)

# %% [markdown]
# ### Data Visualization

# %%
# plot the images
plt.figure(figsize=(18, 18))

num = 0

for i in range(0, 12):
    image,label = next(iter(train_data))
    ax = plt.subplot(6, 6, num + 1)
    plt.imshow(image[0])
    plt.title('class # ' + str(np.argmax(label)))
    plt.axis("off")
    num += 1

# %% [markdown]
# ### MobileNet Model

# %% [markdown]
# The Depthwise Separable Convolution layer

# %%
# Function for Depth-wise Convolution Layer
def DepthWiseConv(kernal_size, stride, x):
    result = DepthwiseConv2D(kernal_size, strides=stride , padding='same')(x)
    result = BatchNormalization()(result)
    result = Activation('relu')(result)
    return result

# %%
# Function for Point-wise Convolution Layer
def PointWiseConv(filters,alpha,kernal_size, stride, x):
    result = Conv2D(int(alpha*filters), kernel_size=kernal_size, strides=stride)(x)
    result = BatchNormalization()(result)
    result = Activation('relu')(result)
    return result

# %% [markdown]
# Model Creation

# %%
def create_Reduced_MobileNet_model(input_shape, alpha ,no_classes):
    
    #first layer (Conv/s2)
    input = Input(shape= input_shape)
    x = Conv2D(32, kernel_size=(3, 3), strides=(2, 2) ,padding='same', use_bias=False)(input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    #second layer (Conv dw/s1) + (Conv /s1)
    x = DepthWiseConv((3,3), (1,1), x)
    x = PointWiseConv(64,1,(1, 1), (1, 1) ,x)

    #third layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(128,1,(1, 1), (1, 1) ,x)
    
    #4th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(256,1,(1, 1), (1, 1) ,x)

    #5th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(512,1,(1, 1), (1, 1) ,x)

    #6th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(1024,1,(1, 1), (1, 1) ,x)

    #7th layer dropout 
    x = Dropout(0.2)(x)

    #8th layer: Avg Pooling
    x = GlobalAveragePooling2D()(x) 

    #9th layer Dense layer
    out = Dense(no_classes,activation='softmax')(x)

    model = Model(input, out, name='mobilenet')

    return model

# %% [markdown]
# Fitting and Training the Model

# %%
MobileNet = create_Reduced_MobileNet_model((image_size,image_size,3),0.25,no_classes)
MobileNet.summary()
# Out:
# Model: "mobilenet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  conv2d_30 (Conv2D)          (None, 64, 64, 32)        864
#
#  batch_normalization_55 (Bat  (None, 64, 64, 32)       128
#  chNormalization)
#
#  activation_55 (Activation)  (None, 64, 64, 32)        0
#
#  depthwise_conv2d_25 (Depthw  (None, 64, 64, 32)       320
#  iseConv2D)
#
#  batch_normalization_56 (Bat  (None, 64, 64, 32)       128
#  chNormalization)
#
#  activation_56 (Activation)  (None, 64, 64, 32)        0
#
#  conv2d_31 (Conv2D)          (None, 64, 64, 64)        2112
#
#  batch_normalization_57 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  activation_57 (Activation)  (None, 64, 64, 64)        0
#
#  depthwise_conv2d_26 (Depthw  (None, 32, 32, 64)       640
#  iseConv2D)
#
#  batch_normalization_58 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_58 (Activation)  (None, 32, 32, 64)        0
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 128)       8320
#
#  batch_normalization_59 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  activation_59 (Activation)  (None, 32, 32, 128)       0
#
#  depthwise_conv2d_27 (Depthw  (None, 16, 16, 128)      1280
#  iseConv2D)
#
#  batch_normalization_60 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_60 (Activation)  (None, 16, 16, 128)       0
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 256)       33024
#
#  batch_normalization_61 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_61 (Activation)  (None, 16, 16, 256)       0
#
#  depthwise_conv2d_28 (Depthw  (None, 8, 8, 256)        2560
#  iseConv2D)
#
#  batch_normalization_62 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_62 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_34 (Conv2D)          (None, 8, 8, 512)         131584
#
#  batch_normalization_63 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_63 (Activation)  (None, 8, 8, 512)         0
#
#  depthwise_conv2d_29 (Depthw  (None, 4, 4, 512)        5120
#  iseConv2D)
#
#  batch_normalization_64 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_64 (Activation)  (None, 4, 4, 512)         0
#
#  conv2d_35 (Conv2D)          (None, 4, 4, 1024)        525312
#
#  batch_normalization_65 (Bat  (None, 4, 4, 1024)       4096
#  chNormalization)
#
#  activation_65 (Activation)  (None, 4, 4, 1024)        0
#
#  dropout_5 (Dropout)         (None, 4, 4, 1024)        0
#
#  global_average_pooling2d_5   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense_5 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 733,418
# Trainable params: 727,402
# Non-trainable params: 6,016
# _________________________________________________________________

# %%
#alpha = 1.00
# Tracking Start Time
start = time.time()

MobileNet.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

# Saving the result
checkpoint_filepath = './tmp/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=True,verbose=1, monitor='accuracy')
history = MobileNet.fit(train_data, epochs=25, validation_data=valid_data, callbacks=[model_checkpoint_callback], shuffle=True)

# Tracking End Time
end = time.time()

MobileNet.load_weights(checkpoint_filepath)
print('Time Consumption: ', end-start)
# Out:
# Epoch 1/25
# 296/296 [==============================] - ETA: 0s - loss: 1.7247 - accuracy: 0.4129
# Epoch 1: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 40s 129ms/step - loss: 1.7247 - accuracy: 0.4129 - val_loss: 3.4720 - val_accuracy: 0.1017
# Epoch 2/25
# 296/296 [==============================] - ETA: 0s - loss: 1.4010 - accuracy: 0.5255
# Epoch 2: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 49s 165ms/step - loss: 1.4010 - accuracy: 0.5255 - val_loss: 2.3495 - val_accuracy: 0.2782
# Epoch 3/25
# 296/296 [==============================] - ETA: 0s - loss: 1.2304 - accuracy: 0.5902
# Epoch 3: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 39s 131ms/step - loss: 1.2304 - accuracy: 0.5902 - val_loss: 1.4180 - val_accuracy: 0.5699
# Epoch 4/25
# 296/296 [==============================] - ETA: 0s - loss: 1.1319 - accuracy: 0.6303
# Epoch 4: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 128ms/step - loss: 1.1319 - accuracy: 0.6303 - val_loss: 1.8119 - val_accuracy: 0.5060
# Epoch 5/25
# 296/296 [==============================] - ETA: 0s - loss: 1.0415 - accuracy: 0.6572
# Epoch 5: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 1.0415 - accuracy: 0.6572 - val_loss: 1.3860 - val_accuracy: 0.5761
# Epoch 6/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9567 - accuracy: 0.6879
# Epoch 6: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.9567 - accuracy: 0.6879 - val_loss: 1.4141 - val_accuracy: 0.5939
# Epoch 7/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9086 - accuracy: 0.7018
# Epoch 7: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.9086 - accuracy: 0.7018 - val_loss: 1.5673 - val_accuracy: 0.5559
# Epoch 8/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8543 - accuracy: 0.7228
# Epoch 8: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.8543 - accuracy: 0.7228 - val_loss: 1.0981 - val_accuracy: 0.6749
# Epoch 9/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8135 - accuracy: 0.7358
# Epoch 9: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.8135 - accuracy: 0.7358 - val_loss: 1.0859 - val_accuracy: 0.6652
# Epoch 10/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7688 - accuracy: 0.7485
# Epoch 10: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.7688 - accuracy: 0.7485 - val_loss: 1.1848 - val_accuracy: 0.6561
# Epoch 11/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7227 - accuracy: 0.7613
# Epoch 11: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.7227 - accuracy: 0.7613 - val_loss: 1.5027 - val_accuracy: 0.6163
# Epoch 12/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7115 - accuracy: 0.7660
# Epoch 12: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.7115 - accuracy: 0.7660 - val_loss: 1.0715 - val_accuracy: 0.6879
# Epoch 13/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6616 - accuracy: 0.7865
# Epoch 13: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.6616 - accuracy: 0.7865 - val_loss: 1.0201 - val_accuracy: 0.6976
# Epoch 14/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6292 - accuracy: 0.7901
# Epoch 14: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.6292 - accuracy: 0.7901 - val_loss: 1.3012 - val_accuracy: 0.6670
# Epoch 15/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6183 - accuracy: 0.7958
# Epoch 15: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.6183 - accuracy: 0.7958 - val_loss: 1.6466 - val_accuracy: 0.5926
# Epoch 16/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5692 - accuracy: 0.8111
# Epoch 16: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.5692 - accuracy: 0.8111 - val_loss: 1.0824 - val_accuracy: 0.7078
# Epoch 17/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5576 - accuracy: 0.8181
# Epoch 17: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 124ms/step - loss: 0.5576 - accuracy: 0.8181 - val_loss: 1.5114 - val_accuracy: 0.6336
# Epoch 18/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5126 - accuracy: 0.8295
# Epoch 18: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.5126 - accuracy: 0.8295 - val_loss: 0.9598 - val_accuracy: 0.7317
# Epoch 19/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5032 - accuracy: 0.8284
# Epoch 19: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.5032 - accuracy: 0.8284 - val_loss: 0.9538 - val_accuracy: 0.7251
# Epoch 20/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4831 - accuracy: 0.8373
# Epoch 20: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.4831 - accuracy: 0.8373 - val_loss: 1.1961 - val_accuracy: 0.6856
# Epoch 21/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4542 - accuracy: 0.8483
# Epoch 21: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 127ms/step - loss: 0.4542 - accuracy: 0.8483 - val_loss: 1.1662 - val_accuracy: 0.6864
# Epoch 22/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4417 - accuracy: 0.8489
# Epoch 22: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4417 - accuracy: 0.8489 - val_loss: 1.3537 - val_accuracy: 0.6545
# Epoch 23/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4194 - accuracy: 0.8613
# Epoch 23: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 124ms/step - loss: 0.4194 - accuracy: 0.8613 - val_loss: 0.9794 - val_accuracy: 0.7378
# Epoch 24/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4006 - accuracy: 0.8614
# Epoch 24: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4006 - accuracy: 0.8614 - val_loss: 1.1179 - val_accuracy: 0.7057
# Epoch 25/25
# 296/296 [==============================] - ETA: 0s - loss: 0.3752 - accuracy: 0.8711
# Epoch 25: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 124ms/step - loss: 0.3752 - accuracy: 0.8711 - val_loss: 1.3911 - val_accuracy: 0.6782
# Time Consumption:  985.9618065357208

# %%
#alpha = 0.75
# Tracking Start Time
start = time.time()

MobileNet.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

# Saving the result
checkpoint_filepath = './tmp/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=True,verbose=1, monitor='accuracy')
history = MobileNet.fit(train_data, epochs=25, validation_data=valid_data, callbacks=[model_checkpoint_callback], shuffle=True)

# Tracking End Time
end = time.time()

MobileNet.load_weights(checkpoint_filepath)
print('Time Consumption: ', end-start)
# Out:
# Epoch 1/25
# 296/296 [==============================] - ETA: 0s - loss: 1.7464 - accuracy: 0.3999
# Epoch 1: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 61s 167ms/step - loss: 1.7464 - accuracy: 0.3999 - val_loss: 3.3145 - val_accuracy: 0.1017
# Epoch 2/25
# 296/296 [==============================] - ETA: 0s - loss: 1.4311 - accuracy: 0.5275
# Epoch 2: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 48s 163ms/step - loss: 1.4311 - accuracy: 0.5275 - val_loss: 2.2106 - val_accuracy: 0.3162
# Epoch 3/25
# 296/296 [==============================] - ETA: 0s - loss: 1.2710 - accuracy: 0.5813
# Epoch 3: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 50s 169ms/step - loss: 1.2710 - accuracy: 0.5813 - val_loss: 1.7055 - val_accuracy: 0.5302
# Epoch 4/25
# 296/296 [==============================] - ETA: 0s - loss: 1.1444 - accuracy: 0.6295
# Epoch 4: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 42s 140ms/step - loss: 1.1444 - accuracy: 0.6295 - val_loss: 1.6330 - val_accuracy: 0.5389
# Epoch 5/25
# 296/296 [==============================] - ETA: 0s - loss: 1.0702 - accuracy: 0.6552
# Epoch 5: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 128ms/step - loss: 1.0702 - accuracy: 0.6552 - val_loss: 1.1591 - val_accuracy: 0.6476
# Epoch 6/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9950 - accuracy: 0.6761
# Epoch 6: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.9950 - accuracy: 0.6761 - val_loss: 1.3568 - val_accuracy: 0.5847
# Epoch 7/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9446 - accuracy: 0.6910
# Epoch 7: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 129ms/step - loss: 0.9446 - accuracy: 0.6910 - val_loss: 1.0870 - val_accuracy: 0.6706
# Epoch 8/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8870 - accuracy: 0.7117
# Epoch 8: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.8870 - accuracy: 0.7117 - val_loss: 1.3343 - val_accuracy: 0.6051
# Epoch 9/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8365 - accuracy: 0.7266
# Epoch 9: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.8365 - accuracy: 0.7266 - val_loss: 1.3516 - val_accuracy: 0.6056
# Epoch 10/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8035 - accuracy: 0.7397
# Epoch 10: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.8035 - accuracy: 0.7397 - val_loss: 1.0643 - val_accuracy: 0.6843
# Epoch 11/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7735 - accuracy: 0.7466
# Epoch 11: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.7735 - accuracy: 0.7466 - val_loss: 1.0133 - val_accuracy: 0.6958
# Epoch 12/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7171 - accuracy: 0.7632
# Epoch 12: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.7171 - accuracy: 0.7632 - val_loss: 1.1406 - val_accuracy: 0.6693
# Epoch 13/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.7696
# Epoch 13: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.6935 - accuracy: 0.7696 - val_loss: 1.3278 - val_accuracy: 0.6227
# Epoch 14/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6740 - accuracy: 0.7815
# Epoch 14: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.6740 - accuracy: 0.7815 - val_loss: 1.1817 - val_accuracy: 0.6563
# Epoch 15/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6360 - accuracy: 0.7917
# Epoch 15: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.6360 - accuracy: 0.7917 - val_loss: 1.0438 - val_accuracy: 0.6968
# Epoch 16/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6057 - accuracy: 0.8023
# Epoch 16: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.6057 - accuracy: 0.8023 - val_loss: 0.9487 - val_accuracy: 0.7419
# Epoch 17/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5792 - accuracy: 0.8116
# Epoch 17: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.5792 - accuracy: 0.8116 - val_loss: 1.0437 - val_accuracy: 0.7019
# Epoch 18/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5524 - accuracy: 0.8144
# Epoch 18: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.5524 - accuracy: 0.8144 - val_loss: 1.1060 - val_accuracy: 0.6983
# Epoch 19/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5162 - accuracy: 0.8235
# Epoch 19: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.5162 - accuracy: 0.8235 - val_loss: 1.1170 - val_accuracy: 0.7152
# Epoch 20/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5015 - accuracy: 0.8327
# Epoch 20: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.5015 - accuracy: 0.8327 - val_loss: 1.0561 - val_accuracy: 0.7070
# Epoch 21/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4723 - accuracy: 0.8419
# Epoch 21: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 127ms/step - loss: 0.4723 - accuracy: 0.8419 - val_loss: 1.1352 - val_accuracy: 0.7083
# Epoch 22/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4516 - accuracy: 0.8527
# Epoch 22: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4516 - accuracy: 0.8527 - val_loss: 1.2154 - val_accuracy: 0.6752
# Epoch 23/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4326 - accuracy: 0.8547
# Epoch 23: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4326 - accuracy: 0.8547 - val_loss: 1.2084 - val_accuracy: 0.6996
# Epoch 24/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4261 - accuracy: 0.8581
# Epoch 24: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.4261 - accuracy: 0.8581 - val_loss: 1.1997 - val_accuracy: 0.7068
# Epoch 25/25
# 296/296 [==============================] - ETA: 0s - loss: 0.3989 - accuracy: 0.8650
# Epoch 25: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.3989 - accuracy: 0.8650 - val_loss: 1.1010 - val_accuracy: 0.7159
# Time Consumption:  996.8253917694092

# %%
# !rm -rf ./tmp/*

# %%
#plot the results 
acc2 = history.history['accuracy']
val_acc2 = history.history['val_accuracy']

loss2 = history.history['loss']
val_loss2 = history.history['val_loss']

plt.figure(figsize=(16, 16))
plt.subplot(2, 2, 1)
plt.plot(acc3, label='Training Acc a=1.00')
plt.plot(acc, label='Training Acc a=0.75')
plt.plot(acc1, label='Training Acc a=0.50')
plt.plot(acc2, label='Training Acc a=0.25')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training Accuracy')

plt.subplot(2, 2, 2)
plt.plot(val_acc3, label='Validation Acc a=1.00')
plt.plot(val_acc, label='Validation Acc a=0.75')
plt.plot(val_acc1, label='Validation Acc a=0.50')
plt.plot(val_acc2, label='Validation Acc a=0.25')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Validation Accuracy')

plt.subplot(2, 2, 3)
plt.plot(loss3, label='Training Loss a=1.00')
plt.plot(loss, label='Training Loss a=0.75')
plt.plot(loss1, label='Training Loss a=0.50')
plt.plot(loss2, label='Training Loss a=0.25')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training Loss')

plt.subplot(2, 2, 4)
plt.plot(val_loss3, label='Validation Loss a=1.00')
plt.plot(val_loss, label='Validation Loss a=0.75')
plt.plot(val_loss1, label='Validation Loss a=0.50')
plt.plot(val_loss2, label='Validation Loss a=0.25')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Validation Loss')

plt.xlabel('epoch')
plt.show()

# %%
del history, model_checkpoint_callback

# %%
#alpha = 0.50
# Tracking Start Time
start = time.time()

MobileNet.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

# Saving the result
checkpoint_filepath = './tmp/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=True,verbose=1, monitor='accuracy')
history = MobileNet.fit(train_data, epochs=25, validation_data=valid_data, callbacks=[model_checkpoint_callback], shuffle=True)

# Tracking End Time
end = time.time()

MobileNet.load_weights(checkpoint_filepath)
print('Time Consumption: ', end-start)
# Out:
# Epoch 1/25
# 296/296 [==============================] - ETA: 0s - loss: 1.7410 - accuracy: 0.4051
# Epoch 1: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 41s 133ms/step - loss: 1.7410 - accuracy: 0.4051 - val_loss: 3.2909 - val_accuracy: 0.1017
# Epoch 2/25
# 296/296 [==============================] - ETA: 0s - loss: 1.4128 - accuracy: 0.5277
# Epoch 2: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 1.4128 - accuracy: 0.5277 - val_loss: 2.1339 - val_accuracy: 0.2741
# Epoch 3/25
# 296/296 [==============================] - ETA: 0s - loss: 1.2605 - accuracy: 0.5852
# Epoch 3: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 1.2605 - accuracy: 0.5852 - val_loss: 1.7547 - val_accuracy: 0.5136
# Epoch 4/25
# 296/296 [==============================] - ETA: 0s - loss: 1.1526 - accuracy: 0.6222
# Epoch 4: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 129ms/step - loss: 1.1526 - accuracy: 0.6222 - val_loss: 1.3000 - val_accuracy: 0.5941
# Epoch 5/25
# 296/296 [==============================] - ETA: 0s - loss: 1.0578 - accuracy: 0.6552
# Epoch 5: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 124ms/step - loss: 1.0578 - accuracy: 0.6552 - val_loss: 1.4559 - val_accuracy: 0.5682
# Epoch 6/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9803 - accuracy: 0.6807
# Epoch 6: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.9803 - accuracy: 0.6807 - val_loss: 1.3711 - val_accuracy: 0.5992
# Epoch 7/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9353 - accuracy: 0.6903
# Epoch 7: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.9353 - accuracy: 0.6903 - val_loss: 1.1451 - val_accuracy: 0.6502
# Epoch 8/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8665 - accuracy: 0.7159
# Epoch 8: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.8665 - accuracy: 0.7159 - val_loss: 1.6722 - val_accuracy: 0.5485
# Epoch 9/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8261 - accuracy: 0.7268
# Epoch 9: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.8261 - accuracy: 0.7268 - val_loss: 1.4339 - val_accuracy: 0.6089
# Epoch 10/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7866 - accuracy: 0.7400
# Epoch 10: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.7866 - accuracy: 0.7400 - val_loss: 1.0287 - val_accuracy: 0.6800
# Epoch 11/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7425 - accuracy: 0.7576
# Epoch 11: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.7425 - accuracy: 0.7576 - val_loss: 1.3041 - val_accuracy: 0.6260
# Epoch 12/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7144 - accuracy: 0.7665
# Epoch 12: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.7144 - accuracy: 0.7665 - val_loss: 1.1744 - val_accuracy: 0.6718
# Epoch 13/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6735 - accuracy: 0.7789
# Epoch 13: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.6735 - accuracy: 0.7789 - val_loss: 1.1408 - val_accuracy: 0.6668
# Epoch 14/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6576 - accuracy: 0.7848
# Epoch 14: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.6576 - accuracy: 0.7848 - val_loss: 1.2250 - val_accuracy: 0.6642
# Epoch 15/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6031 - accuracy: 0.8059
# Epoch 15: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.6031 - accuracy: 0.8059 - val_loss: 1.0391 - val_accuracy: 0.7073
# Epoch 16/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5930 - accuracy: 0.8046
# Epoch 16: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.5930 - accuracy: 0.8046 - val_loss: 1.4654 - val_accuracy: 0.6234
# Epoch 17/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5674 - accuracy: 0.8152
# Epoch 17: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.5674 - accuracy: 0.8152 - val_loss: 0.9252 - val_accuracy: 0.7452
# Epoch 18/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5405 - accuracy: 0.8192
# Epoch 18: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.5405 - accuracy: 0.8192 - val_loss: 1.0736 - val_accuracy: 0.7011
# Epoch 19/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5162 - accuracy: 0.8282
# Epoch 19: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.5162 - accuracy: 0.8282 - val_loss: 1.2540 - val_accuracy: 0.6734
# Epoch 20/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4919 - accuracy: 0.8361
# Epoch 20: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.4919 - accuracy: 0.8361 - val_loss: 1.3471 - val_accuracy: 0.6721
# Epoch 21/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4731 - accuracy: 0.8444
# Epoch 21: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4731 - accuracy: 0.8444 - val_loss: 1.2164 - val_accuracy: 0.6876
# Epoch 22/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4360 - accuracy: 0.8569
# Epoch 22: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.4360 - accuracy: 0.8569 - val_loss: 1.1059 - val_accuracy: 0.7269
# Epoch 23/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4224 - accuracy: 0.8557
# Epoch 23: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4224 - accuracy: 0.8557 - val_loss: 1.1210 - val_accuracy: 0.7182
# Epoch 24/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4109 - accuracy: 0.8613
# Epoch 24: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.4109 - accuracy: 0.8613 - val_loss: 1.0405 - val_accuracy: 0.7483
# Epoch 25/25
# 296/296 [==============================] - ETA: 0s - loss: 0.3972 - accuracy: 0.8647
# Epoch 25: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.3972 - accuracy: 0.8647 - val_loss: 1.2289 - val_accuracy: 0.6945
# Time Consumption:  938.0528035163879

# %%
#alpha = 0.25
# Tracking Start Time
start = time.time()

MobileNet.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

# Saving the result
checkpoint_filepath = './tmp/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=True,verbose=1, monitor='accuracy')
history = MobileNet.fit(train_data, epochs=25, validation_data=valid_data, callbacks=[model_checkpoint_callback], shuffle=True)

# Tracking End Time
end = time.time()

MobileNet.load_weights(checkpoint_filepath)
print('Time Consumption: ', end-start)
# Out:
# Epoch 1/25
# 296/296 [==============================] - ETA: 0s - loss: 1.7460 - accuracy: 0.4031
# Epoch 1: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 43s 139ms/step - loss: 1.7460 - accuracy: 0.4031 - val_loss: 3.4512 - val_accuracy: 0.1017
# Epoch 2/25
# 296/296 [==============================] - ETA: 0s - loss: 1.4274 - accuracy: 0.5249
# Epoch 2: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 1.4274 - accuracy: 0.5249 - val_loss: 1.9211 - val_accuracy: 0.3325
# Epoch 3/25
# 296/296 [==============================] - ETA: 0s - loss: 1.2830 - accuracy: 0.5747
# Epoch 3: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 124ms/step - loss: 1.2830 - accuracy: 0.5747 - val_loss: 1.7779 - val_accuracy: 0.4815
# Epoch 4/25
# 296/296 [==============================] - ETA: 0s - loss: 1.1497 - accuracy: 0.6209
# Epoch 4: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 1.1497 - accuracy: 0.6209 - val_loss: 1.5112 - val_accuracy: 0.5419
# Epoch 5/25
# 296/296 [==============================] - ETA: 0s - loss: 1.0665 - accuracy: 0.6551
# Epoch 5: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 1.0665 - accuracy: 0.6551 - val_loss: 1.3319 - val_accuracy: 0.5870
# Epoch 6/25
# 296/296 [==============================] - ETA: 0s - loss: 1.0026 - accuracy: 0.6693
# Epoch 6: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 1.0026 - accuracy: 0.6693 - val_loss: 1.7725 - val_accuracy: 0.5279
# Epoch 7/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9427 - accuracy: 0.6900
# Epoch 7: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.9427 - accuracy: 0.6900 - val_loss: 1.2497 - val_accuracy: 0.6283
# Epoch 8/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8830 - accuracy: 0.7143
# Epoch 8: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 124ms/step - loss: 0.8830 - accuracy: 0.7143 - val_loss: 1.8254 - val_accuracy: 0.5131
# Epoch 9/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8469 - accuracy: 0.7237
# Epoch 9: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.8469 - accuracy: 0.7237 - val_loss: 1.0350 - val_accuracy: 0.6935
# Epoch 10/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8073 - accuracy: 0.7353
# Epoch 10: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 127ms/step - loss: 0.8073 - accuracy: 0.7353 - val_loss: 1.1927 - val_accuracy: 0.6596
# Epoch 11/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7795 - accuracy: 0.7410
# Epoch 11: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.7795 - accuracy: 0.7410 - val_loss: 1.0931 - val_accuracy: 0.6790
# Epoch 12/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7287 - accuracy: 0.7598
# Epoch 12: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.7287 - accuracy: 0.7598 - val_loss: 1.4227 - val_accuracy: 0.5972
# Epoch 13/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7076 - accuracy: 0.7659
# Epoch 13: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.7076 - accuracy: 0.7659 - val_loss: 1.0316 - val_accuracy: 0.6884
# Epoch 14/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6708 - accuracy: 0.7785
# Epoch 14: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.6708 - accuracy: 0.7785 - val_loss: 1.4543 - val_accuracy: 0.6107
# Epoch 15/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6354 - accuracy: 0.7892
# Epoch 15: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.6354 - accuracy: 0.7892 - val_loss: 1.2039 - val_accuracy: 0.6711
# Epoch 16/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6234 - accuracy: 0.7946
# Epoch 16: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.6234 - accuracy: 0.7946 - val_loss: 1.1330 - val_accuracy: 0.6884
# Epoch 17/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5835 - accuracy: 0.8028
# Epoch 17: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.5835 - accuracy: 0.8028 - val_loss: 1.0414 - val_accuracy: 0.7022
# Epoch 18/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5578 - accuracy: 0.8178
# Epoch 18: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.5578 - accuracy: 0.8178 - val_loss: 1.1423 - val_accuracy: 0.6820
# Epoch 19/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5371 - accuracy: 0.8218
# Epoch 19: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 124ms/step - loss: 0.5371 - accuracy: 0.8218 - val_loss: 1.0815 - val_accuracy: 0.7042
# Epoch 20/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5193 - accuracy: 0.8288
# Epoch 20: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.5193 - accuracy: 0.8288 - val_loss: 1.0386 - val_accuracy: 0.7180
# Epoch 21/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4930 - accuracy: 0.8401
# Epoch 21: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 125ms/step - loss: 0.4930 - accuracy: 0.8401 - val_loss: 1.0418 - val_accuracy: 0.7317
# Epoch 22/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4733 - accuracy: 0.8414
# Epoch 22: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4733 - accuracy: 0.8414 - val_loss: 1.1066 - val_accuracy: 0.7124
# Epoch 23/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4451 - accuracy: 0.8485
# Epoch 23: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4451 - accuracy: 0.8485 - val_loss: 1.4134 - val_accuracy: 0.6683
# Epoch 24/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4372 - accuracy: 0.8495
# Epoch 24: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4372 - accuracy: 0.8495 - val_loss: 1.2626 - val_accuracy: 0.6846
# Epoch 25/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4053 - accuracy: 0.8631
# Epoch 25: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 124ms/step - loss: 0.4053 - accuracy: 0.8631 - val_loss: 1.1760 - val_accuracy: 0.6953
# Time Consumption:  938.0683076381683

# %% [markdown]
# ### CNN Model

# %% [markdown]
# Standard Convolution Layer

# %%
def standard_Conv(filter,kernal_size, stride, x):
  x = Conv2D(filter, kernel_size=kernal_size, strides=stride ,padding='same', use_bias=False)(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  return x

# %% [markdown]
# Model Creation

# %%
def create_CNN_model(input_shape ,no_classes):
    
    filters = [32,64,128,256,512,1024]
    strides = [2,1,2,2,2,2]
    layers = len(filters)
    
    x = Input(shape= input_shape)

    for i in range(layers):
      x = Conv2D(filters[i], kernel_size=(3, 3), strides=(strides[i], strides[i]) ,padding='same', use_bias=False)(x)
      x = BatchNormalization()(x)
      x = Activation('relu')(x)

    # Dropout Layer 
    x = Dropout(0.2)(x)

    # Avg Pooling layer
    x = GlobalAveragePooling2D()(x) 

    # Dense layer
    out = Dense(no_classes,activation='softmax')(x)

    model = Model(input, out, name='mobilenet')

    return model

# %% [markdown]
# Fitting and Training The Model

# %%
MobileNet = create_Reduced_MobileNet_model((image_size,image_size,3),1,no_classes)
MobileNet.summary()

# %%
# Tracking Start Time
start = time.time()

MobileNet.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

# Saving the result
checkpoint_filepath = './tmp/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=True,verbose=1, monitor='accuracy')
history = MobileNet.fit(train_data, epochs=25, validation_data=valid_data, callbacks=[model_checkpoint_callback], shuffle=True)

# Tracking End Time
end = time.time()

MobileNet.load_weights(checkpoint_filepath)
print('Time Consumption: ', end-start)

# %%
#plot the results 
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')

plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
