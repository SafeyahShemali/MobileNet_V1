# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import keras
from keras import datasets, layers, models
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, Activation , DepthwiseConv2D
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, SeparableConv2D,  GlobalAveragePooling2D, AveragePooling2D
from keras.optimizers import Adam, RMSprop, SGD
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda, GlobalAveragePooling2D
from keras.preprocessing.image import ImageDataGenerator

# %%
data, info = tfds.load("imagenette/160px-v2", with_info=True, as_supervised=True)
train_data, valid_data = data['train'], data['validation']
# Out:
# Downloading and preparing dataset 94.42 MiB (download: 94.42 MiB, generated: 102.10 MiB, total: 196.52 MiB) to ~/tensorflow_datasets/imagenette/160px-v2/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/9469 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/imagenette/160px-v2/1.0.0.incompleteN3DEQF/imagenette-train.tfrecord*...:   0%…
# Generating validation examples...:   0%|          | 0/3925 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/imagenette/160px-v2/1.0.0.incompleteN3DEQF/imagenette-validation.tfrecord*...:…
# Dataset imagenette downloaded and prepared to ~/tensorflow_datasets/imagenette/160px-v2/1.0.0. Subsequent calls will reuse this data.

# %%
train_dataset = train_data.map(
    lambda image, label: (tf.image.resize(image, (128, 128)), label))

validation_dataset = valid_data.map(
    lambda image, label: (tf.image.resize(image, (128, 128)), label)
)

# %%
num_train = train_dataset.__len__().numpy()
num_val = validation_dataset.__len__().numpy()

num_classes = info.features['label'].num_classes
print('Total number of classes in dataset: ', num_classes)

print('Number of training samples: ', num_train)
print('Number of validation samples: ', num_val)
# Out:
# Total number of classes in dataset:  10
# Number of training samples:  9469
# Number of validation samples:  3925

# %%
get_label_name = info.features['label'].int2str

text_labels = [get_label_name(i) for i in range(num_classes)]
for idx,i in enumerate(text_labels):
    print('Label: {} , Name: {}'.format(idx, i))
# Out:
# Label: 0 , Name: n01440764
# Label: 1 , Name: n02102040
# Label: 2 , Name: n02979186
# Label: 3 , Name: n03000684
# Label: 4 , Name: n03028079
# Label: 5 , Name: n03394916
# Label: 6 , Name: n03417042
# Label: 7 , Name: n03425413
# Label: 8 , Name: n03445777
# Label: 9 , Name: n03888257

# %%
X_train = list(map(lambda x: x[0], train_dataset))
y_train = list(map(lambda x: x[1], train_dataset))


X_valid = list(map(lambda x: x[0], validation_dataset))
y_valid = list(map(lambda x: x[1], validation_dataset))

y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_valid = tf.keras.utils.to_categorical(y_valid, num_classes)

# %%
train_len = info.splits['train'].num_examples
validation_len = info.splits['validation'].num_examples

print('Train size: {}'.format(train_len))
print('Validation size: {}'.format(validation_len))
# Out:
# Train size: 9469
# Validation size: 3925

# %%
print('Y Train shape: {}'.format(y_train.shape))
print('Y Validation shape: {}'.format(y_valid.shape))
# Out:
# Y Train shape: (9469, 10)
# Y Validation shape: (3925, 10)

# %%
train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=30,
      height_shift_range=0.3)

valid_datagen = ImageDataGenerator(
      rescale=1./255)

train_data = tf.keras.preprocessing.image.NumpyArrayIterator(
    x=np.array(X_train), y=np.array(y_train), image_data_generator=train_datagen,batch_size=32
)

valid_data = tf.keras.preprocessing.image.NumpyArrayIterator(
    x=np.array(X_valid), y=np.array(y_valid), image_data_generator=valid_datagen,batch_size=32
)

# %%
plt.figure(figsize=(18, 18))

num = 0

for i in range(0, 12):
    image,label = next(iter(train_data))
    ax = plt.subplot(6, 6, num + 1)
    plt.imshow(image[0])
    plt.title(str(get_label_name(np.argmax(label))) + ' - class # ' + str(np.argmax(label)))
    plt.axis("off")
    num += 1

# %%
def create_MobileNet_model(input_shape, alpha, no_classes):
    
    print('layer 1 input', input_shape)

    #first layer (Conv/s2)
    input = Input(shape= input_shape)
    x = Conv2D(int(alpha*32), kernel_size=(3, 3), strides=(2, 2) ,padding='same', use_bias=False)(input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    print('layer 2 input', x.shape)
    #second layer (Conv dw/s1) + (Conv /s1)
    x = DepthWiseConv((3,3), (1,1), x)
    x = PointWiseConv(int(alpha*64),(1, 1), (1, 1) ,x)

    print('layer 3 input', x.shape)
    #third layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(int(alpha*128),(1, 1), (1, 1) ,x)
    
    # print('layer 4 input', x.shape)
    # #4th layer (Conv dw/s1) + (Conv /s1)
    # x = DepthWiseConv((3,3), (1,1), x)
    # x = PointWiseConv(128,(1, 1), (1, 1) ,x)

    print('layer 5 input', x.shape)
    #5th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(int(alpha*256),(1, 1), (1, 1) ,x)

    # print('layer 6 input', x.shape)
    # #6th layer (Conv dw/s1) + (Conv /s1)
    # x = DepthWiseConv((3,3), (1,1), x)
    # x = PointWiseConv(256,(1, 1), (1, 1) ,x)

    print('layer 7 input', x.shape)
    #7th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(int(alpha*512),(1, 1), (1, 1) ,x)

    # print('layer 8 stack input', x.shape)
    # #8thlayer: 5 * (Conv dw/s1) + (Conv dw /s1)
    # for _ in range(5):
    #   x = DepthWiseConv((3,3), (1,1), x)
    #   x = PointWiseConv(512,(1, 1), (1, 1) ,x)

    print('layer 9 input', x.shape)
    #9th layer (Conv dw/s2) + (Conv /s1)
    x = DepthWiseConv((3,3), (2,2), x)
    x = PointWiseConv(int(alpha*1024),(1, 1), (1, 1) ,x)

    x = Dropout(0.2)(x)

    # print('layer 10 input', x.shape)
    # #10th layer (Conv dw/s2) + (Conv /s1)
    # x = DepthWiseConv((3,3), (1,1), x)
    # x = PointWiseConv(1024,(1, 1), (1, 1) ,x)

    print('Avg Pooling input', x.shape)
    #11th layer: Avg Pooling (7*7)
    x = GlobalAveragePooling2D()(x) 

    print('Flatten input', x.shape)
    #print('Flatten layer input', x.shape)
    #Flatten layer / s1? 
    #x = Flatten()(x)

    print('Dense 12 input', x.shape)
    #12th layer : Affine layer
    out = Dense(no_classes,activation='softmax')(x)

    print('out', out.shape)

    model = Model(input, out, name='mobilenet')

    return model

# %%
def DepthWiseConv(kernal_size, stride, x):
    result = DepthwiseConv2D(kernal_size, strides=stride , padding='same')(x)
    result = BatchNormalization()(result)
    result = Activation('relu')(result)
    return result

# %%
def PointWiseConv(filters,kernal_size, stride, x):
    result = Conv2D(filters, kernel_size=kernal_size, strides=stride)(x)
    result = BatchNormalization()(result)
    result = Activation('relu')(result)
    return result

# %%
MobileNet = create_MobileNet_model((128,128,3),1.0,10)
MobileNet.summary()
# Out:
# layer 1 input (128, 128, 3)
# layer 2 input (None, 64, 64, 32)
# layer 3 input (None, 64, 64, 64)
# layer 5 input (None, 32, 32, 128)
# layer 7 input (None, 16, 16, 256)
# layer 9 input (None, 8, 8, 512)
# Avg Pooling input (None, 4, 4, 1024)
# Flatten input (None, 1024)
# Dense 12 input (None, 1024)
# out (None, 10)
# Model: "mobilenet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  conv2d (Conv2D)             (None, 64, 64, 32)        864
#
#  batch_normalization (BatchN  (None, 64, 64, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 64, 64, 32)        0
#
#  depthwise_conv2d (Depthwise  (None, 64, 64, 32)       320
#  Conv2D)
#
#  batch_normalization_1 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 64, 64, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        2112
#
#  batch_normalization_2 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 64, 64, 64)        0
#
#  depthwise_conv2d_1 (Depthwi  (None, 32, 32, 64)       640
#  seConv2D)
#
#  batch_normalization_3 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 32, 32, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       8320
#
#  batch_normalization_4 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 32, 32, 128)       0
#
#  depthwise_conv2d_2 (Depthwi  (None, 16, 16, 128)      1280
#  seConv2D)
#
#  batch_normalization_5 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_5 (Activation)   (None, 16, 16, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       33024
#
#  batch_normalization_6 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 16, 16, 256)       0
#
#  depthwise_conv2d_3 (Depthwi  (None, 8, 8, 256)        2560
#  seConv2D)
#
#  batch_normalization_7 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_7 (Activation)   (None, 8, 8, 256)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 512)         131584
#
#  batch_normalization_8 (Batc  (None, 8, 8, 512)        2048
#  hNormalization)
#
#  activation_8 (Activation)   (None, 8, 8, 512)         0
#
#  depthwise_conv2d_4 (Depthwi  (None, 4, 4, 512)        5120
#  seConv2D)
#
#  batch_normalization_9 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_9 (Activation)   (None, 4, 4, 512)         0
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 1024)        525312
#
#  batch_normalization_10 (Bat  (None, 4, 4, 1024)       4096
#  chNormalization)
#
#  activation_10 (Activation)  (None, 4, 4, 1024)        0
#
#  dropout (Dropout)           (None, 4, 4, 1024)        0
#
#  global_average_pooling2d (G  (None, 1024)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 10)                10250
#
# =================================================================
# Total params: 733,418
# Trainable params: 727,402
# Non-trainable params: 6,016
# _________________________________________________________________

# %%
# MobileNet.compile(optimizer='adam',
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])
# MobileNet.fit(train_data, epochs=20, validation_data=valid_data, verbose=1)

MobileNet.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])


checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=True,verbose=1, monitor='accuracy')

history = MobileNet.fit(train_data, epochs=25, validation_data=valid_data, callbacks=[model_checkpoint_callback], shuffle=True)

MobileNet.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/25
# 296/296 [==============================] - ETA: 0s - loss: 1.7319 - accuracy: 0.4104
# Epoch 1: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 48s 129ms/step - loss: 1.7319 - accuracy: 0.4104 - val_loss: 4.0266 - val_accuracy: 0.1017
# Epoch 2/25
# 296/296 [==============================] - ETA: 0s - loss: 1.4174 - accuracy: 0.5306
# Epoch 2: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 128ms/step - loss: 1.4174 - accuracy: 0.5306 - val_loss: 1.7195 - val_accuracy: 0.4028
# Epoch 3/25
# 296/296 [==============================] - ETA: 0s - loss: 1.2703 - accuracy: 0.5797
# Epoch 3: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 129ms/step - loss: 1.2703 - accuracy: 0.5797 - val_loss: 1.7696 - val_accuracy: 0.4999
# Epoch 4/25
# 296/296 [==============================] - ETA: 0s - loss: 1.1590 - accuracy: 0.6146
# Epoch 4: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 129ms/step - loss: 1.1590 - accuracy: 0.6146 - val_loss: 1.6782 - val_accuracy: 0.5088
# Epoch 5/25
# 296/296 [==============================] - ETA: 0s - loss: 1.0570 - accuracy: 0.6510
# Epoch 5: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 129ms/step - loss: 1.0570 - accuracy: 0.6510 - val_loss: 1.2683 - val_accuracy: 0.5952
# Epoch 6/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9928 - accuracy: 0.6744
# Epoch 6: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 129ms/step - loss: 0.9928 - accuracy: 0.6744 - val_loss: 1.3503 - val_accuracy: 0.5926
# Epoch 7/25
# 296/296 [==============================] - ETA: 0s - loss: 0.9267 - accuracy: 0.7021
# Epoch 7: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 129ms/step - loss: 0.9267 - accuracy: 0.7021 - val_loss: 1.4050 - val_accuracy: 0.5806
# Epoch 8/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8690 - accuracy: 0.7095
# Epoch 8: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 129ms/step - loss: 0.8690 - accuracy: 0.7095 - val_loss: 1.2805 - val_accuracy: 0.6168
# Epoch 9/25
# 296/296 [==============================] - ETA: 0s - loss: 0.8285 - accuracy: 0.7289
# Epoch 9: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 39s 132ms/step - loss: 0.8285 - accuracy: 0.7289 - val_loss: 1.8287 - val_accuracy: 0.5264
# Epoch 10/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7886 - accuracy: 0.7433
# Epoch 10: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 39s 132ms/step - loss: 0.7886 - accuracy: 0.7433 - val_loss: 1.1473 - val_accuracy: 0.6583
# Epoch 11/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7440 - accuracy: 0.7576
# Epoch 11: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 128ms/step - loss: 0.7440 - accuracy: 0.7576 - val_loss: 1.5379 - val_accuracy: 0.5852
# Epoch 12/25
# 296/296 [==============================] - ETA: 0s - loss: 0.7145 - accuracy: 0.7666
# Epoch 12: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 129ms/step - loss: 0.7145 - accuracy: 0.7666 - val_loss: 1.1188 - val_accuracy: 0.6769
# Epoch 13/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6810 - accuracy: 0.7782
# Epoch 13: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 128ms/step - loss: 0.6810 - accuracy: 0.7782 - val_loss: 1.9656 - val_accuracy: 0.5381
# Epoch 14/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6477 - accuracy: 0.7855
# Epoch 14: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 128ms/step - loss: 0.6477 - accuracy: 0.7855 - val_loss: 1.1464 - val_accuracy: 0.6665
# Epoch 15/25
# 296/296 [==============================] - ETA: 0s - loss: 0.6140 - accuracy: 0.7999
# Epoch 15: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 127ms/step - loss: 0.6140 - accuracy: 0.7999 - val_loss: 1.2983 - val_accuracy: 0.6456
# Epoch 16/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5988 - accuracy: 0.7990
# Epoch 16: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 129ms/step - loss: 0.5988 - accuracy: 0.7990 - val_loss: 1.0090 - val_accuracy: 0.7203
# Epoch 17/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5678 - accuracy: 0.8084
# Epoch 17: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 127ms/step - loss: 0.5678 - accuracy: 0.8084 - val_loss: 1.2206 - val_accuracy: 0.6634
# Epoch 18/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5371 - accuracy: 0.8231
# Epoch 18: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 129ms/step - loss: 0.5371 - accuracy: 0.8231 - val_loss: 1.2701 - val_accuracy: 0.6410
# Epoch 19/25
# 296/296 [==============================] - ETA: 0s - loss: 0.5160 - accuracy: 0.8281
# Epoch 19: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 127ms/step - loss: 0.5160 - accuracy: 0.8281 - val_loss: 1.3835 - val_accuracy: 0.6288
# Epoch 20/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4921 - accuracy: 0.8384
# Epoch 20: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4921 - accuracy: 0.8384 - val_loss: 1.1887 - val_accuracy: 0.6955
# Epoch 21/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4636 - accuracy: 0.8490
# Epoch 21: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4636 - accuracy: 0.8490 - val_loss: 1.0147 - val_accuracy: 0.7182
# Epoch 22/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4457 - accuracy: 0.8512
# Epoch 22: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4457 - accuracy: 0.8512 - val_loss: 1.2211 - val_accuracy: 0.6841
# Epoch 23/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4195 - accuracy: 0.8620
# Epoch 23: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.4195 - accuracy: 0.8620 - val_loss: 1.2100 - val_accuracy: 0.6902
# Epoch 24/25
# 296/296 [==============================] - ETA: 0s - loss: 0.4045 - accuracy: 0.8645
# Epoch 24: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 38s 127ms/step - loss: 0.4045 - accuracy: 0.8645 - val_loss: 1.7702 - val_accuracy: 0.6120
# Epoch 25/25
# 296/296 [==============================] - ETA: 0s - loss: 0.3970 - accuracy: 0.8663
# Epoch 25: saving model to ./tmp/checkpoint
# 296/296 [==============================] - 37s 126ms/step - loss: 0.3970 - accuracy: 0.8663 - val_loss: 1.2277 - val_accuracy: 0.6986

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')

plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# !rm -rf ./tmp/checkpoint

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('MobileNet Model 128 Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('MobileNet Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

print("run timing with gpu - 48*25s ")
# Out:
# run timing with gpu - 48*25s
